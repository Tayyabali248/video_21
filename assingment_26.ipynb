# %% [markdown]
# # Assingment
# pick file from FAO and form data

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
data = sns.load_dataset('data_on_machinery')
data.drop(['Year Code','Flag',], axis=1)
# Out:
#     Domain Code     Domain  Area Code (FAO)      Area  Element Code  \
# 0            RM  Machinery              165  Pakistan          5622
# 1            RM  Machinery              165  Pakistan          5622
# 2            RM  Machinery              165  Pakistan          5622
# 3            RM  Machinery              165  Pakistan          5622
# 4            RM  Machinery              165  Pakistan          5622
# ..          ...        ...              ...       ...           ...
# 793          RM  Machinery              165  Pakistan          5922
# 794          RM  Machinery              165  Pakistan          5922
# 795          RM  Machinery              165  Pakistan          5922
# 796          RM  Machinery              165  Pakistan          5922
# 797          RM  Machinery              165  Pakistan          5922
#
#           Element  Item Code                                Item  Year  \
# 0    Import Value    2455017  Agricultural machinery nes (trade)  1964
# ...

# %%
data2 = data.drop(['Year Code','Flag',], axis=1).head()
data2.groupby(['Item','Value']).mean()
# Out:
#                                            Area Code (FAO)  Element Code  \
# Item                               Value
# Agricultural machinery nes (trade) 347.0             165.0        5622.0
#                                    353.0             165.0        5622.0
#                                    574.0             165.0        5622.0
#                                    2187.0            165.0        5622.0
#                                    2388.0            165.0        5622.0
#
#                                            Item Code    Year
# Item                               Value
# Agricultural machinery nes (trade) 347.0   2455017.0  1964.0
#                                    353.0   2455017.0  1965.0
#                                    574.0   2455017.0  1971.0
#                                    2187.0  2455017.0  1970.0
#                                    2388.0  2455017.0  1969.0
